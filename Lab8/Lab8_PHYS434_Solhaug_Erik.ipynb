# %% [markdown]
# # Lab 8 - Event Selection Optimalization

# %% [markdown]
# ##### PHYS434 - Advanced Laboratory: Computational Data Analysis
# ##### Professor: Miguel Morales
# <br>

# %% [markdown]
# ##### Due date: 12/13/2021
# ##### By Erik Solhaug
# <br>

# %% [markdown]
# In this lab, we will use a pseudo-experiment dataset to detect the Higgs boson.
#
# From the previous labs, we have the data presented below.

# %%
# %matplotlib inline
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
from scipy import stats
import h5py
import pickle
import math

import pandas as pd

#this sets the size of the plot to something useful
plt.rcParams["figure.figsize"] = (20,15)

# %%
user_dir = '/home/jovyan/Phys434_Autumn2021/'
data_dir = user_dir + 'LHC_data/'
data_dir
# Out:
# '/home/jovyan/Phys434_Autumn2021/LHC_data/'

# %% [markdown]
# # From Lab 7

# %%
with open(f'{data_dir}/higgs_100000_pt_250_500.pkl', 'rb') as f:
    higgs = pickle.load(f)

# %%
with open(f'{data_dir}/qcd_100000_pt_250_500.pkl', 'rb') as f:
    qcd = pickle.load(f)

# %%
higgs
# Out:
#                pt       eta       phi        mass       ee2       ee3  \
# 0      472.074292  0.137052 -2.535145  125.150365  0.126581  0.002633
# 1      470.405678 -0.039157  0.069669  130.552672  0.118071  0.002379
# 2      438.008357 -0.181139 -3.031083  125.703063  0.167344  0.004623
# 3      484.860421  0.251986  2.855706  126.215853  0.119238  0.002066
# 4      486.141137 -1.917812 -2.221953  132.182504  0.103632  0.001438
# ...           ...       ...       ...         ...       ...       ...
# 99995  478.658254 -0.837586 -2.609921  125.707302  0.138041  0.001494
# 99996  465.171259  0.429341 -1.446681  129.749906  0.135890  0.002071
# 99997  466.920808 -0.805493 -0.754703   49.069161  0.020281  0.000121
# 99998  471.611853  0.801813 -3.077883  117.186361  0.102276  0.002399
# 99999  467.029906 -0.432315  2.483939   64.187269  0.031847  0.000260
#
#               d2  angularity        t1        t2        t3       t21  \
# 0       1.298020    0.008218  0.739787  0.283689  0.174944  0.383474
# 1       1.445626    0.013822  0.747927  0.234281  0.193354  0.313240
# 2       0.986597    0.004545  1.001379  0.440523  0.218649  0.439917
# 3       1.218467    0.006740  0.761892  0.228160  0.193810  0.299465
# 4       1.291784    0.000398  0.722656  0.166851  0.148080  0.230886
# ...          ...         ...       ...       ...       ...       ...
# 99995   0.567994    0.000953  1.192189  0.131294  0.109689  0.110129
# 99996   0.825176    0.005110  0.751448  0.140336  0.115123  0.186755
# 99997  14.506839    0.004768  0.864723  0.568722  0.395942  0.657693
# 99998   2.242231    0.006947  0.759346  0.318427  0.274153  0.419343
# 99999   8.061788    0.011270  0.783730  0.437477  0.391823  0.558199
#
#             t32  KtDeltaR
# 0      0.616674  0.557407
# 1      0.825308  0.704650
# 2      0.496338  0.487496
# 3      0.849449  0.594872
# 4      0.887497  0.678118
# ...         ...       ...
# 99995  0.835446  0.504678
# 99996  0.820334  0.586032
# 99997  0.696196  0.018073
# 99998  0.860960  0.641892
# 99999  0.895643  0.855158
#
# [100000 rows x 14 columns]

# %%
qcd
# Out:
#                pt       eta       phi        mass       ee2       ee3  \
# 0      489.631389  1.955969  1.803007  125.298720  0.099409  0.003247
# 1      401.041884 -1.170413  0.188817   88.047054  0.101181  0.002527
# 2      447.487556  1.861736 -2.326646   85.794174  0.069372  0.001375
# 3      402.652836  1.276421 -1.124176   42.947328  0.032095  0.000266
# 4      484.257672 -1.272225  1.966794   59.542227  0.038348  0.000358
# ...           ...       ...       ...         ...       ...       ...
# 99995  418.171225  1.804938 -1.555512   67.399102  0.047555  0.000669
# 99996  492.119236 -0.037258  0.037888   90.775772  0.095329  0.001090
# 99997  492.932552 -0.912632  0.578690  106.611253  0.078793  0.002331
# 99998  402.673975 -1.736921 -2.103913   66.278542  0.066585  0.000851
# 99999  454.801644  1.059727  1.462793   62.786390  0.062568  0.000652
#
#              d2  angularity        t1        t2        t3       t21       t32  \
# 0      3.304886    0.000528  0.846096  0.586658  0.439468  0.693370  0.749105
# 1      2.439089    0.001561  0.852379  0.517657  0.336052  0.607308  0.649178
# 2      4.118371    0.000197  0.979133  0.815123  0.700152  0.832495  0.858953
# 3      8.038338    0.001144  1.020193  0.664347  0.617499  0.651197  0.929482
# 4      6.353842    0.001619  0.875408  0.436270  0.376816  0.498362  0.863723
# ...         ...         ...       ...       ...       ...       ...       ...
# 99995  6.216951    0.000335  0.794253  0.734325  0.533141  0.924548  0.726028
# 99996  1.258409    0.005327  0.849051  0.285315  0.177652  0.336041  0.622651
# 99997  4.764786    0.004449  0.951293  0.789768  0.620329  0.830205  0.785457
# 99998  2.881152    0.000324  0.831466  0.488685  0.429960  0.587739  0.879831
# 99999  2.661545    0.001104  0.962824  0.439327  0.389692  0.456290  0.887021
#
#        KtDeltaR
# 0      0.333731
# 1      0.477481
# 2      0.117091
# 3      0.054606
# 4      0.095201
# ...         ...
# 99995  0.039376
# 99996  0.321335
# 99997  0.053165
# 99998  0.212806
# 99999  0.175638
#
# [100000 rows x 14 columns]

# %%
fig, ax = plt.subplots(7, 2)
fig.tight_layout(pad=3.0)

for i in range(0,qcd.columns.size):
    name = qcd.columns[i]
    X1 = qcd[f'{name}']
    X2 = higgs[f'{name}']
    
    bins = 100
    
    row = math.floor(i/2)
    col = i%2
    
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].hist(X1, bins, color='deepskyblue', linewidth = 3, label = 'qcd')
    ax[row, col].hist(X2, bins, color='crimson', alpha = 0.7, linewidth = 3, label='higgs')
    ax[row, col].set_title(f'{name}', fontsize = 15, fontweight='bold')
    ax[row, col].grid(linestyle='--', alpha=0.2)
ax[0, 1].legend();

# %% [markdown]
# - **pt** - We have already described **$p_T$** above, but as a reminder, this is the transverse momentum - the momentum perpendicular to the colliding particle beams - of the jet.

# %% [markdown]
# - **phi** - the azimuthal angle about the axis of the colliding beams at which the detector detects the outcoming jets. The angle is seemingly random and is fairly evenly distributed across the values $-\pi<\phi<\pi$. Adding up all the collision counts across this space should yield the number of jets which is 100,000 as previously stated (this should be true for all other frames plotted above).

# %% [markdown]
# - **'eta'** - is described as the _pseudorapidity_ which is related to and depends on _theta_ - the angle of the jet relative to the colliding beams. Thus, since the space in _eta_ spans from negative infinity to infinity it makes sense that the distribution is a Gaussian centered on zero, as this will be the most probably value of _eta_. An _eta_ of 0 corresponds to a jet with a completely perpendicular angle from the colliding beams (90 degrees) while an _eta_ of specifically 1 and -1 corresponds to an angle of 40 and 130 degrees relative to the beam. Hence, _eta_ of $\infty$ and $-\infty$ corresponds to jets parallel and antiparallel respectively to the beam. Hence, $-\infty < \eta < \infty$ corresponds to $-\pi < \theta < \pi$.

# %% [markdown]
# - **angularity** - a family of infrared-safe quantities that have characteristic distributions for two-body decays

# %% [markdown]
#  - **mass** - given in GeV and the most probable Higgs mass is stated as 125 GeV. This will of course have some uncertainty which is reflected in the Higgs dataset's mass data. The mass of the quantum chromodynamics (QCD) background particles are more spread out as the biproducts of pp-collisions can result in a variety of particles with different masses. The mass is reconstructed from the muon-corrected combined mass of the jet.

# %% [markdown]
# - **ee2 and ee3** - correspond to the energy correlation functions (the i-th energy correlation function; $i=2,3$) which are based on the energies and pair-wise angles of particles within a jet

# %% [markdown]
# - **d2** - is a function of the energy correlation functions $ECF_3 ·(\frac{ECF_1}{ECF_2})^3$. Thus, _d2_ is related to the parameters _ee2_ and _ee3_.

# %% [markdown]
# - **t1**, **t2**, **t3**, **t21** and **t32** - these are the $\tau$-parameters which gives the n-subjettiness of the jet. N-subjettiness sums the angular distances of jet constituents to their nearest subjet axis

# %% [markdown]
# - **KtDeltaR** - $\Delta R$ of two subjets within the large-$R$ jet. This corresponds to the minimal relative transverse momentum between particles.

# %% [markdown]
# For more information on the jet parameters, see p. 17 in this paper https://arxiv.org/pdf/1906.11005v2.pdf.

# %% [markdown]
# ## Problem 1

# %%
plt.rcParams["figure.figsize"] = (12,7)

# %%
N_Higgs = 100
N_QCD = 20_000
N_data = 100_000

w_QCD = N_QCD/N_data
w_Higgs = N_Higgs/N_data

# %%
fig, ax = plt.subplots(1, 1)
fig.tight_layout(pad=3.0)

X1 = qcd['mass']
X2 = higgs['mass']

bins = 200

w1 = np.ones(X1.size)*w_QCD
w2 = np.ones(X2.size)*w_Higgs

ax.hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
ax.set_xlabel('Mass')
ax.set_ylabel('Events')
ax.set_title('Stacked mass plot', fontsize = 15, fontweight='bold')
ax.grid(linestyle='--', alpha=0.2)
ax.legend();

# %%
bkgd1 = stats.poisson(mu=N_QCD)
significance1 = bkgd1.sf(N_QCD+N_Higgs)
significance1
# Out:
# 0.23847212190687442

# %%
# Shorthand
approx_significance1 = N_Higgs/(N_QCD)**(1/2)
approx_significance1
# Out:
# 0.7071067811865475

# %% [markdown]
# The _shorthand_ way of estimating the significance of the detection (of 100 Higgs vs. 20000 QCD events) gives a quick way to infer the signal-to-noise ratio of the experiment. The higher number of signal events and the lower number of signal events, the more significant the event is.
#
# The shorthand method yields a higher significance (higher value) than using Poisson statistics (which yields a lower significance, lower value). Since our significance for either method is this low, we will need to make cuts in the N_QCD and as few cuts in the N_Higgs as possible in order to increase our significance.

# %% [markdown]
# ## Problem 2

# %% [markdown]
# In order to increase the significance of our Higgs events, we will make cuts in the data.

# %% [markdown]
# We want to make cuts in the below qcd such as to exclude as much background without excluding much of the higgs distribution. Then, our significance $\frac{N_{Higgs}}{\sqrt{N_{QCD}}}$ will increase.

# %%
N_Higgs = 100
N_QCD = 20000

fig, ax = plt.subplots(1, 1)
fig.tight_layout(pad=3.0)

X1 = qcd['mass']
X2 = higgs['mass']

bins = 200

w1 = np.ones(X1.size)*w_QCD
w2 = np.ones(X2.size)*w_Higgs

ax.hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
ax.set_xlabel('Mass')
ax.set_ylabel('Events')
ax.set_title('Mass selection of stacked mass plot', fontsize = 15, fontweight='bold')
ax.grid(linestyle='--', alpha=0.2)
ax.set_xlim([120, 130])
ax.legend();

# %%
# Making cuts in background data
mask1 = qcd['mass'] > 120
mask2 = qcd['mass'] < 400
cut = qcd[mask1]
cut1 = cut[mask2]
# Out:
# <ipython-input-14-e3524d47f58e>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cut1 = cut[mask2]

# %%
cut1
# Out:
#                pt       eta       phi        mass       ee2       ee3  \
# 0      489.631389  1.955969  1.803007  125.298720  0.099409  0.003247
# 20     415.076589 -1.506753  1.907424  129.731372  0.144225  0.005892
# 26     452.954752 -2.113726 -0.656256  140.604098  0.145026  0.005989
# 29     389.628555  2.307074  2.140521  193.213930  0.280462  0.024363
# 32     458.823291 -0.952371 -0.452309  136.732974  0.148186  0.007501
# ...           ...       ...       ...         ...       ...       ...
# 99979  489.045184 -1.047401  1.918182  136.531828  0.138522  0.005242
# 99981  459.074215  0.364665 -1.763238  245.666241  0.335468  0.025205
# 99988  460.350538  0.572863 -2.222752  147.251130  0.134181  0.005520
# 99990  489.957763  0.547008 -2.709347  183.394738  0.156273  0.009033
# 99994  492.399120  0.122302  2.294604  128.224524  0.112629  0.003125
#
#              d2  angularity        t1        t2        t3       t21       t32  \
# 0      3.304886    0.000528  0.846096  0.586658  0.439468  0.693370  0.749105
# 20     1.964075    0.000722  0.749090  0.394665  0.368057  0.526859  0.932580
# 26     1.963491    0.000306  0.910954  0.458554  0.362265  0.503378  0.790015
# 29     1.104346    0.000280  1.465348  0.245479  0.157898  0.167523  0.643226
# 32     2.305226    0.004092  0.942433  0.699523  0.612565  0.742252  0.875689
# ...         ...         ...       ...       ...       ...       ...       ...
# 99979  1.972036    0.002335  1.284882  0.670594  0.384743  0.521911  0.573735
# 99981  0.667634    0.019321  0.909263  0.246286  0.163337  0.270863  0.663202
# 99988  2.284693    0.016441  0.910971  0.537477  0.360971  0.590004  0.671602
# 99990  2.366984    0.022600  0.873900  0.456772  0.364739  0.522682  0.798515
# 99994  2.187318    0.013146  0.942893  0.612489  0.258006  0.649584  0.421242
#
#        KtDeltaR
# 0      0.333731
# 20     0.720351
# 26     0.598624
# 29     0.786797
# 32     0.212681
# ...         ...
# 99979  0.286969
# 99981  0.983290
# 99988  0.817680
# 99990  0.837876
# 99994  0.161663
#
# [24204 rows x 14 columns]

# %% [markdown]
# Each cut gives us a dataframe that contains a selection of events/jets with masses within the value of our mass cut.

# %%
mask1 = qcd['mass'] > 120
mask2 = qcd['mass'] < 150
cut = qcd[mask1]
cut2 = cut[mask2]

mask1 = qcd['mass'] > 120
mask2 = qcd['mass'] < 128
cut = qcd[mask1]
cut3 = cut[mask2]

mask1 = qcd['mass'] > 122
mask2 = qcd['mass'] < 128
cut = qcd[mask1]
cut4 = cut[mask2]
# Out:
# <ipython-input-16-f7ca04484aa5>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cut2 = cut[mask2]
# <ipython-input-16-f7ca04484aa5>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cut3 = cut[mask2]
# <ipython-input-16-f7ca04484aa5>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cut4 = cut[mask2]

# %%
cuts = [cut1, cut2, cut3, cut4]

# %%
mask1 = higgs['mass'] > 120
mask2 = higgs['mass'] < 400
cut = higgs[mask1]
cuthiggs1 = cut[mask2]

mask1 = higgs['mass'] > 120
mask2 = higgs['mass'] < 150
cut = higgs[mask1]
cuthiggs2 = cut[mask2]

mask1 = higgs['mass'] > 120
mask2 = higgs['mass'] < 128
cut = higgs[mask1]
cuthiggs3 = cut[mask2]

mask1 = higgs['mass'] > 122
mask2 = higgs['mass'] < 128
cut = higgs[mask1]
cuthiggs4 = cut[mask2]
# Out:
# <ipython-input-18-b9098ae1c111>:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cuthiggs1 = cut[mask2]
# <ipython-input-18-b9098ae1c111>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cuthiggs2 = cut[mask2]
# <ipython-input-18-b9098ae1c111>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cuthiggs3 = cut[mask2]
# <ipython-input-18-b9098ae1c111>:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cuthiggs4 = cut[mask2]

# %%
cuts_higgs = [cuthiggs1, cuthiggs2, cuthiggs3, cuthiggs4]

# %% [markdown]
# The first cut cuts the data down like this:

# %%
bins = 100

X1 = cuts[0]['mass']
X2 = cuts_higgs[0]['mass']

w1 = np.ones(X1.size)*w_QCD
w2 = np.ones(X2.size)*w_Higgs

n1, temp1, temp2 = plt.hist([X1,X2], stacked=True, bins = 40, weights=[w1,w2], color=['deepskyblue','crimson'], label = ['qcd', 'stacked qcd + higgs'])
plt.xlabel('Mass')
plt.ylabel('Events')
plt.title('Mass plot QCD', fontsize = 15, fontweight='bold')
plt.grid(linestyle='--', alpha=0.2)
plt.legend();

# %%
nqcd = []
nstacked = []

for index in range(0, len(cuts)):
    
    X1 = cuts[index]['mass']
    X2 = cuts_higgs[index]['mass']
    
    w1 = np.ones(X1.size)*w_QCD
    w2 = np.ones(X2.size)*w_Higgs

    narray, temp1, temp2 = plt.hist([X1,X2], stacked=True, bins=round(X1.size/500), weights=[w1, w2], label=['qcd', 'stacked qcd + higgs'], alpha=0.5)
    plt.grid(linestyle='--', alpha=0.2)
    plt.legend();
    
    nqcd.append(narray[0])
    nstacked.append(narray[1])
plt.xlabel('Mass')
plt.ylabel('Events')
plt.title('Mass selection of stacked mass plot', fontsize = 15, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Mass selection of stacked mass plot')

# %%
Nqcd = []
for i in range(0, len(nqcd)):
    Nqcd.append(np.sum(nqcd[i]))
    
Nstacked = []
for i in range(0, len(nstacked)):
    Nstacked.append(np.sum(nstacked[i]))

# %%
Nstacked, Nqcd
# Out:
# ([4918.864999997735, 2459.664999999972, 879.7169999999962, 653.0569999999454],
#  [4840.799999997788, 2381.600000000025, 811.4000000000475, 587.1999999999965])

# %%
approx_significance = []
for i in range(0, len(Nqcd)):
    sig = (Nstacked[i]-Nqcd[i])/(Nqcd[i])**(1/2)
    approx_significance.append(sig)

# %%
plt.scatter(Nqcd, approx_significance, color='deepskyblue', label = 'qcd')
plt.xlabel('N')
plt.ylabel('Significance')
plt.title('Significance after cuts', fontsize = 15, fontweight='bold')
plt.grid(linestyle='--', alpha=0.2)
plt.legend();

# %% [markdown]
# We see that making cuts that rejects more of the background without rejecting Higgs data yields higher significances, and this relationship seems to follow an exponential curve.

# %% [markdown]
# Our cuts are thus between 122 and 128 $\frac{GeV}{c^2}$

# %% [markdown]
# ## Problem 3

# %% [markdown]
# We now make two sets of _stacked_ histograms: Set 1 without mass cuts and Set 2 with our chosen mass cuts.
#
# We will then attempt to identify another feature that can be discriminative and help increase our significance.

# %% [markdown]
# ### Set 1

# %%
plt.rcParams["figure.figsize"] = (20,15)

fig, ax = plt.subplots(7, 2)
fig.tight_layout(pad=3.0)

for i in range(0,qcd.columns.size):
    name = qcd.columns[i]
    X1 = qcd[f'{name}']
    X2 = higgs[f'{name}']
    
    w1 = np.ones(X1.size)*w_QCD
    w2 = np.ones(X2.size)*w_Higgs
    
    bins = 100
    
    row = math.floor(i/2)
    col = i%2
    
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], alpha=0.7, weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
    ax[row, col].set_title(f'{name}', fontsize = 15, fontweight='bold')
    ax[row, col].grid(linestyle='--', alpha=0.2)
ax[0, 1].legend();

# %%
fig, ax = plt.subplots(7, 2)
fig.tight_layout(pad=3.0)

for i in range(0,qcd.columns.size):
    name = qcd.columns[i]
    X1 = qcd[f'{name}']
    X2 = higgs[f'{name}']
    
    w1 = np.ones(X1.size)*w_QCD
    w2 = np.ones(X2.size)*w_Higgs
    
    bins = 100
    
    row = math.floor(i/2)
    col = i%2
    
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], alpha=0.7, weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
    ax[row, col].set_title(f'{name}', fontsize = 15, fontweight='bold')
    ax[row, col].grid(linestyle='--', alpha=0.2)
    ax[row, col].set_yscale('log')
ax[0, 1].legend();

# %% [markdown]
# We can clearly make cuts in eta, ee2, ee3, d2, t2 and t21.

# %% [markdown]
# ### Set 2

# %% [markdown]
# We apply our optimal mass cut to create Set 2:

# %% [raw]
# cuts[3] and cuts_higgs[3] will give us our optimal mass cut.

# %%
plt.rcParams["figure.figsize"] = (20,15)

fig, ax = plt.subplots(7, 2)
fig.tight_layout(pad=3.0)

for i in range(0,qcd.columns.size):
    
    name = qcd.columns[i]
    X1 = cuts[3][f'{name}']
    X2 = cuts_higgs[3][f'{name}']
    
    w1 = np.ones(X1.size)*w_QCD
    w2 = np.ones(X2.size)*w_Higgs
    
    bins = 20
    
    row = math.floor(i/2)
    col = i%2
    
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], alpha=0.7, weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
    ax[row, col].set_title(f'{name}', fontsize = 15, fontweight='bold')
    ax[row, col].grid(linestyle='--', alpha=0.2)
ax[0, 1].legend();

# %%
plt.rcParams["figure.figsize"] = (20,15)

fig, ax = plt.subplots(7, 2)
fig.tight_layout(pad=3.0)

mask1 = qcd['mass'] > 122
mask2 = qcd['mass'] < 128
cut = qcd[mask1]
cut4 = cut[mask2]

mask1 = higgs['mass'] > 122
mask2 = higgs['mass'] < 128
cut = higgs[mask1]
cut4higgs = cut[mask2]

for i in range(0,qcd.columns.size):
    
    name = qcd.columns[i]
    X1 = cut4[f'{name}']
    X2 = cut4higgs[f'{name}']
    
    w1 = np.ones(X1.size)*w_QCD
    w2 = np.ones(X2.size)*w_Higgs
    
    bins = 20
    
    row = math.floor(i/2)
    col = i%2
    
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], alpha=0.7, weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
    ax[row, col].set_title(f'{name}', fontsize = 15, fontweight='bold')
    ax[row, col].grid(linestyle='--', alpha=0.2)
    ax[row, col].set_yscale('log')
ax[0, 1].legend();
# Out:
# <ipython-input-29-2eadd820120f>:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cut4 = cut[mask2]
# <ipython-input-29-2eadd820120f>:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cut4higgs = cut[mask2]

# %% [markdown]
# ## Problem 4

# %% [markdown]
# While we did not find any discriminative features for Set 1, there are more prevalent discriminative features present in Set 2 now that the mass cuts have been performed. From looking at the above data, we can make cuts for t3, KtDeltaR, ee2 and ee3.

# %%
cut4, cut4higgs
# Out:
# (               pt       eta       phi        mass       ee2       ee3  \
#  0      489.631389  1.955969  1.803007  125.298720  0.099409  0.003247
#  84     320.287154  0.592017 -0.740326  126.608757  0.196841  0.014375
#  123    393.304233 -0.714448  3.032173  123.276979  0.134964  0.007245
#  187    470.889623 -0.840914 -2.686093  127.819027  0.120419  0.004856
#  203    443.189779  0.000071  1.750447  123.012295  0.103696  0.003209
#  ...           ...       ...       ...         ...       ...       ...
#  99861  497.352253  0.397299 -1.083313  126.713121  0.111460  0.003336
#  99869  349.704744  0.430005  2.152565  125.272633  0.165878  0.010155
#  99892  475.749348  1.762662  0.753676  124.326725  0.152276  0.004898
#  99897  424.843089  0.425303  2.417773  125.591304  0.100439  0.003527
#  99906  424.359369 -1.514124 -0.821506  123.828527  0.142509  0.005612
#
#               d2  angularity        t1        t2        t3       t21       t32  \
#  0      3.304886    0.000528  0.846096  0.586658  0.439468  0.693370  0.749105
#  84     1.884845    0.018676  0.872732  0.627275  0.484783  0.718749  0.772839
#  123    2.946991    0.008468  0.853993  0.539301  0.352255  0.631505  0.653169
#  187    2.781032    0.006173  0.838984  0.470287  0.328882  0.560543  0.699322
#  203    2.877927    0.023476  0.887070  0.437340  0.302704  0.493016  0.692147
#  ...         ...         ...       ...       ...       ...       ...       ...
#  99861  2.409399    0.007655  0.769048  0.370844  0.285148  0.482211  0.768916
#  99869  2.224870    0.016373  0.850429  0.465605  0.291079  0.547494  0.625163
#  99892  1.387050    0.000157  1.067959  0.470530  0.360936  0.440588  0.767084
#  99897  3.481425    0.016450  0.676658  0.352607  0.310337  0.521101  0.880121
#  99906  1.939126    0.000969  0.851855  0.408537  0.366024  0.479585  0.895939
#
#         KtDeltaR
#  0      0.333731
#  84     0.792751
#  123    0.656792
#  187    0.314338
#  203    0.906572
#  ...         ...
#  99861  0.646268
#  99869  0.522642
#  99892  0.361790
#  99897  0.899232
#  99906  0.478267
#
#  [2936 rows x 14 columns],
#                 pt       eta       phi        mass       ee2       ee3  \
#  0      472.074292  0.137052 -2.535145  125.150365  0.126581  0.002633
#  2      438.008357 -0.181139 -3.031083  125.703063  0.167344  0.004623
#  3      484.860421  0.251986  2.855706  126.215853  0.119238  0.002066
#  5      475.798645  1.678998  0.309122  125.676535  0.144900  0.001321
#  6      470.814879 -2.123238 -3.034306  127.654008  0.158736  0.003725
#  ...           ...       ...       ...         ...       ...       ...
#  99990  476.714821  0.017553  2.663535  125.900800  0.136183  0.001918
#  99991  329.146295 -0.345632  2.028976  126.248441  0.222235  0.007895
#  99993  438.966552  1.232495  3.024192  126.430944  0.160702  0.004927
#  99994  483.898015 -0.216674 -0.796111  125.629127  0.125778  0.001278
#  99995  478.658254 -0.837586 -2.609921  125.707302  0.138041  0.001494
#
#               d2  angularity        t1        t2        t3       t21       t32  \
#  0      1.298020    0.008218  0.739787  0.283689  0.174944  0.383474  0.616674
#  2      0.986597    0.004545  1.001379  0.440523  0.218649  0.439917  0.496338
#  3      1.218467    0.006740  0.761892  0.228160  0.193810  0.299465  0.849449
#  5      0.434366    0.000124  1.089226  0.095011  0.086523  0.087228  0.910669
#  6      0.931205    0.000052  1.072702  0.404063  0.128649  0.376677  0.318388
#  ...         ...         ...       ...       ...       ...       ...       ...
#  99990  0.759438    0.004177  0.784562  0.141923  0.116186  0.180895  0.818656
#  99991  0.719282    0.006825  0.865370  0.196993  0.096368  0.227640  0.489193
#  99993  1.187090    0.000714  1.234348  0.395782  0.157371  0.320641  0.397621
#  99994  0.642064    0.002957  0.779179  0.101895  0.092026  0.130772  0.903143
#  99995  0.567994    0.000953  1.192189  0.131294  0.109689  0.110129  0.835446
#
#         KtDeltaR
#  0      0.557407
#  2      0.487496
#  3      0.594872
#  5      0.507167
#  6      0.467436
#  ...         ...
#  99990  0.529387
#  99991  0.719228
#  99993  0.499350
#  99994  0.529690
#  99995  0.504678
#
#  [65857 rows x 14 columns])

# %%
def cut_data(data, name, lower, upper):
    mask1 = data[f'{name}'] > lower
    mask2 = data[f'{name}'] < upper
    tempcut = data[mask1]
    new_cut = tempcut[mask2]
    return new_cut

# %%
# Cutting down qcd
old_cut = cuts[3]

new_cut = cut_data(old_cut, 'eta', -2.0, 2.0)
new_cut = cut_data(new_cut, 'ee2', 0.0, 0.18)
new_cut = cut_data(new_cut, 'ee3', 0.00, 0.01)
new_cut = cut_data(new_cut, 'd2', 0, 5)
new_cut = cut_data(new_cut, 't2', 0.00, 0.55)
new_cut = cut_data(new_cut, 't21', 0.00, 0.75)

new_qcd = new_cut
# Out:
# <ipython-input-31-84bfcdc42013>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_cut = tempcut[mask2]

# %%
# Cutting down Higgs data
old_cut = cuts_higgs[3]

new_cut = cut_data(old_cut, 'eta', -2.0, 2.0)
new_cut = cut_data(new_cut, 'ee2', 0.0, 0.18)
new_cut = cut_data(new_cut, 'ee3', 0.00, 0.01)
new_cut = cut_data(new_cut, 'd2', 0, 5)
new_cut = cut_data(new_cut, 't2', 0.00, 0.55)
new_cut = cut_data(new_cut, 't21', 0.00, 0.75)

new_higgs = new_cut
# Out:
# <ipython-input-31-84bfcdc42013>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_cut = tempcut[mask2]

# %%
plt.rcParams["figure.figsize"] = (20,15)

fig, ax = plt.subplots(7, 2)
fig.tight_layout(pad=3.0)

for i in range(0,qcd.columns.size):
    
    name = qcd.columns[i]
    X1 = new_qcd[f'{name}']
    X2 = new_higgs[f'{name}']
    
    w1 = np.ones(X1.size)*w_QCD
    w2 = np.ones(X2.size)*w_Higgs
    
    bins = 20
    
    row = math.floor(i/2)
    col = i%2
    
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], alpha=0.7, weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
    ax[row, col].set_title(f'{name}', fontsize = 15, fontweight='bold')
    ax[row, col].grid(linestyle='--', alpha=0.2)
ax[0, 1].legend();

# %% [markdown]
# This is our data with the optimal data cuts.
#
# Now, we calculate the significance.

# %%
plt.rcParams["figure.figsize"] = (20,10)

N_Higgs = 100
N_QCD = 20000

bins = 70

X1 = new_qcd['pt']
X2 = new_higgs['pt']

bins = 20

w1 = np.ones(X1.size)*w_QCD
w2 = np.ones(X2.size)*w_Higgs

n1array, temp1, temp2 = plt.hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
plt.tick_params(labelsize = 15)
plt.tick_params(labelsize = 15)
plt.xlabel(r'$p_T$', fontsize = 15)
plt.ylabel('Events', fontsize = 15)
plt.title('Optimalized data cut', fontsize = 15, fontweight='bold')
plt.grid(linestyle='--', alpha=0.2)
plt.legend();

# %%
nqcd = n1array[0]
nstacked = n1array[1]

# %%
Nqcd = np.sum(nqcd)
Nstacked = np.sum(nstacked)
Nqcd, Nstacked
# Out:
# (299.39999999999156, 357.6009999999466)

# %%
new_significance = (Nstacked-Nqcd)/Nqcd**(1/2)
new_significance
# Out:
# 3.363601586779472

# %%
approx_significance[-1], new_significance # Significance after mass cut, significance after all other cuts
# Out:
# (2.717746341880217, 3.363601586779472)

# %% [markdown]
# As we can see, our significance increases by a lot - from 2.7 to 3.4 - after making the appropriate cuts.

# %% [raw]
# Notes: np.where(mass<130 ... all conditions for cut)

# %% [markdown]
# # Lab 8

# %% [markdown]
# ## Importing pseudo-experiment data

# %%
highLumi = pd.read_hdf(f'{data_dir}/data_highLumi_pt_250_500.h5')
lowLumi = pd.read_hdf(f'{data_dir}/data_lowLumi_pt_250_500.h5')

# %%
highLumi
# Out:
#                pt       eta       phi        mass       ee2       ee3  \
# 0      491.273762  0.885859 -1.607844   58.540714  0.027848  0.000236
# 1      443.077741 -0.850850 -1.808610  109.261432  0.111414  0.003361
# 2      487.700656 -0.848095  3.101697   80.398065  0.059299  0.000973
# 3      474.234962  1.501633 -1.656456   90.085535  0.061264  0.001368
# 4      485.597724  1.021424  1.742641  119.889999  0.133209  0.003223
# ...           ...       ...       ...         ...       ...       ...
# 40339  463.278465  1.715067 -2.254925   79.321004  0.066043  0.001196
# 40340  418.496927 -2.246578  1.679789   44.635757  0.030060  0.000199
# 40341  474.840070 -0.981801  3.135062   55.302586  0.031332  0.000290
# 40342  460.901330  0.764519 -0.736565   72.333900  0.037743  0.000560
# 40343  499.565949  0.649520  1.438259  116.189770  0.128379  0.003361
#
#               d2  angularity        t1        t2        t3       t21  \
# 0      10.916629    0.002658  0.723524  0.576035  0.451149  0.796152
# 1       2.430250    0.003674  1.081477  0.488437  0.431396  0.451639
# 2       4.666474    0.004545  0.885087  0.637212  0.476032  0.719942
# 3       5.948416    0.001163  1.354343  0.698983  0.668163  0.516104
# 4       1.363644    0.001526  0.905440  0.354629  0.219775  0.391665
# ...          ...         ...       ...       ...       ...       ...
# 40339   4.150582    0.000477  0.837033  0.602315  0.573286  0.719583
# 40340   7.316158    0.000066  0.922342  0.801027  0.579431  0.868470
# 40341   9.421780    0.003184  0.814772  0.695005  0.503360  0.853005
# 40342  10.421032    0.005506  0.910557  0.675996  0.491189  0.742398
# 40343   1.588696    0.002460  1.128550  0.750582  0.434417  0.665085
#
#             t32  KtDeltaR
# 0      0.783197  0.105238
# 1      0.883217  0.254729
# 2      0.747054  0.231983
# 3      0.955908  0.096045
# 4      0.619733  0.406962
# ...         ...       ...
# 40339  0.951804  0.266005
# 40340  0.723360  0.037072
# 40341  0.724255  0.102287
# 40342  0.726616  0.059109
# 40343  0.578774  0.240327
#
# [40344 rows x 14 columns]

# %%
lowLumi
# Out:
#               pt       eta       phi        mass       ee2       ee3  \
# 0     499.974801 -0.340430 -3.124063   35.763836  0.016922  0.000061
# 1     470.525978  1.447995 -0.463162   79.069978  0.052447  0.000801
# 2     455.009985 -1.672870 -2.260314   56.401982  0.030301  0.000229
# 3     387.414081 -1.002107 -2.688377   77.412447  0.092790  0.001888
# 4     442.472789 -1.103515 -2.367580   86.479013  0.049532  0.000909
# ...          ...       ...       ...         ...       ...       ...
# 4055  485.528722  1.349769  1.178191  101.540846  0.093551  0.002513
# 4056  472.231371  1.874326 -0.785502   48.174004  0.025348  0.000161
# 4057  407.594270  0.494450 -1.839265   67.141046  0.061750  0.000890
# 4058  417.108347 -1.391452 -0.368711  126.643493  0.163618  0.007312
# 4059  485.253101  2.061039 -1.685139   43.609392  0.016284  0.000080
#
#              d2  angularity        t1        t2        t3       t21       t32  \
# 0     12.505765    0.003937  1.181578  0.797111  0.724045  0.674615  0.908337
# 1      5.549873    0.000965  0.924677  0.752034  0.679503  0.813294  0.903554
# 2      8.234025    0.000417  0.892902  0.630183  0.538919  0.705769  0.855178
# 3      2.363279    0.002206  0.975771  0.461347  0.338407  0.472803  0.733519
# 4      7.483889    0.002174  0.782566  0.668635  0.432825  0.854414  0.647326
# ...         ...         ...       ...       ...       ...       ...       ...
# 4055   3.069102    0.002492  1.006359  0.811150  0.664146  0.806025  0.818770
# 4056   9.860763    0.000308  1.036714  0.918382  0.721017  0.885858  0.785095
# 4057   3.778698    0.003875  0.957798  0.730431  0.548445  0.762615  0.750852
# 4058   1.669434    0.001432  1.184487  0.673570  0.573632  0.568659  0.851630
# 4059  18.411152    0.000203  0.879115  0.719687  0.556776  0.818650  0.773637
#
#       KtDeltaR
# 0     0.026663
# 1     0.136669
# 2     0.106421
# 3     0.324391
# 4     0.041830
# ...        ...
# 4055  0.164820
# 4056  0.038309
# 4057  0.298864
# 4058  0.373660
# 4059  0.047215
#
# [4060 rows x 14 columns]

# %% [markdown]
# ### Without data cuts

# %% [markdown]
# We now take a look at our **high luminosity** data.

# %% [raw]
# N_Higgs = 100
# N_QCD = 20_000
# N_data = 100_000
#
# N_highLumi = 40_344
#
# w_QCD = N_QCD/N_data
# w_Higgs = N_Higgs/N_data

# %% [markdown]
# We need to adjust our weights to make the normalization of the simulated data match the high luminosity (and eventually low luminosity) data.

# %%
N_highLumi = len(highLumi['pt'])

# %%
# w_highLumi should not be used - only use weights for simulated QCD and Higgs

# %%
new_w_QCD = w_QCD*N_highLumi/(N_QCD+N_Higgs)
new_w_Higgs = w_Higgs*N_highLumi/(N_QCD+N_Higgs)

# %%
new_w_QCD, new_w_Higgs
# Out:
# (0.4014328358208955, 0.002007164179104478)

# %%
plt.rcParams["figure.figsize"] = (20,15)

fig, ax = plt.subplots(7, 2)
fig.tight_layout(pad=3.0)

for i in range(0,qcd.columns.size):
    name = qcd.columns[i]
    X1 = qcd[f'{name}']
    X2 = higgs[f'{name}']
    X3 = highLumi[f'{name}']
    
    w1 = np.ones(X1.size)*new_w_QCD
    w2 = np.ones(X2.size)*new_w_Higgs
    w3 = np.ones(X3.size)
    
    bins = 100
    
    row = math.floor(i/2)
    col = i%2
    
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].tick_params(labelsize = 15)
    temp = ax[row, col].hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], alpha=0.7, weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
    ax[row, col].hist(X3, bins=temp[1], color='orange', weights=w3, linewidth = 3, label = 'high_Lumi', alpha=0.5)
    ax[row, col].set_title(f'{name}', fontsize = 15, fontweight='bold')
    ax[row, col].grid(linestyle='--', alpha=0.2)
ax[0, 1].legend();

# %% [markdown]
# Now, we make the same cuts in the data as we did for the simulated QCD and Higgs data.

# %%
old_cut = highLumi

new_cut = cut_data(old_cut, 'mass', 122, 128)
new_cut = cut_data(new_cut, 'eta', -2.0, 2.0)
new_cut = cut_data(new_cut, 'ee2', 0.0, 0.18)
new_cut = cut_data(new_cut, 'ee3', 0.00, 0.01)
new_cut = cut_data(new_cut, 'd2', 0, 5)
new_cut = cut_data(new_cut, 't2', 0.00, 0.55)
new_cut = cut_data(new_cut, 't21', 0.00, 0.75)

new_highLumi = new_cut
# Out:
# <ipython-input-31-84bfcdc42013>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_cut = tempcut[mask2]
# <ipython-input-31-84bfcdc42013>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_cut = tempcut[mask2]

# %%
len(new_qcd['pt']), len(new_higgs['pt']), len(new_highLumi['pt'])
# Out:
# (1497, 58201, 704)

# %% [markdown]
# ### With data cuts

# %%
plt.rcParams["figure.figsize"] = (20,15)

fig, ax = plt.subplots(7, 2)
fig.tight_layout(pad=3.0)

for i in range(0,qcd.columns.size):
    name = qcd.columns[i]
    X1 = new_qcd[f'{name}']
    X2 = new_higgs[f'{name}']
    X3 = new_highLumi[f'{name}']
    
    w1 = np.ones(X1.size)*new_w_QCD
    w2 = np.ones(X2.size)*new_w_Higgs
    w3 = np.ones(X3.size)
    
    bins = 100
    
    row = math.floor(i/2)
    col = i%2
    
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].tick_params(labelsize = 15)
    temp = ax[row, col].hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], alpha=0.7, weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
    ax[row, col].hist(X3, bins=temp[1], color='orange', weights=w3, linewidth = 3, label = 'high_Lumi', alpha=0.5)
    ax[row, col].set_title(f'{name}', fontsize = 15, fontweight='bold')
    ax[row, col].grid(linestyle='--', alpha=0.2)
ax[0, 1].legend();

# %% [markdown]
# We calculate the observed significance of the data. We assume Poisson statistics.

# %% [markdown]
# We look at the excess of events in mass around 125 Gev/c^2

# %%
background = stats.poisson(mu = 8) #Background seems to be at about 9 events
prob = background.sf(19)# Our excess is about 18 events
significance1 = abs(stats.norm.ppf(prob))
significance1
# Out:
# 3.4776241050966084

# %% [markdown]
# Our observed significance is around 3.5 which is only slightly higher than the expected significance after the mass cuts which was 3.4.

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Now, we repeat the process with the **low luminosity** data.

# %%
N_lowLumi = len(lowLumi['pt'])

# %%
new_w_QCD2 = w_QCD*N_lowLumi/(N_QCD+N_Higgs)
new_w_Higgs2 = w_Higgs*N_lowLumi/(N_QCD+N_Higgs)

# %% [markdown]
# ### Without data cuts

# %%
plt.rcParams["figure.figsize"] = (20,15)

fig, ax = plt.subplots(7, 2)
fig.tight_layout(pad=3.0)

for i in range(0,qcd.columns.size):
    name = qcd.columns[i]
    X1 = qcd[f'{name}']
    X2 = higgs[f'{name}']
    X3 = lowLumi[f'{name}']
    
    w1 = np.ones(X1.size)*new_w_QCD2
    w2 = np.ones(X2.size)*new_w_Higgs2
    w3 = np.ones(X3.size)
    
    bins = 100
    
    row = math.floor(i/2)
    col = i%2
    
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].tick_params(labelsize = 15)
    temp = ax[row, col].hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], alpha=0.7, weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
    ax[row, col].hist(X3, bins=temp[1], color='thistle', weights=w3, linewidth = 3, label = 'low_Lumi', alpha=0.5)
    ax[row, col].set_title(f'{name}', fontsize = 15, fontweight='bold')
    ax[row, col].grid(linestyle='--', alpha=0.2)
ax[0, 1].legend();

# %% [markdown]
# Now, we make the same cuts in the data as we did for the simulated QCD and Higgs data.

# %%
old_cut = lowLumi

new_cut = cut_data(old_cut, 'mass', 122, 128)
new_cut = cut_data(new_cut, 'eta', -2.0, 2.0)
new_cut = cut_data(new_cut, 'ee2', 0.0, 0.18)
new_cut = cut_data(new_cut, 'ee3', 0.00, 0.01)
new_cut = cut_data(new_cut, 'd2', 0, 5)
new_cut = cut_data(new_cut, 't2', 0.00, 0.55)
new_cut = cut_data(new_cut, 't21', 0.00, 0.75)

new_lowLumi = new_cut
# Out:
# <ipython-input-31-84bfcdc42013>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_cut = tempcut[mask2]
# <ipython-input-31-84bfcdc42013>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new_cut = tempcut[mask2]

# %% [markdown]
# ### With data cuts

# %%
plt.rcParams["figure.figsize"] = (20,15)

fig, ax = plt.subplots(7, 2)
fig.tight_layout(pad=3.0)

for i in range(0,qcd.columns.size):
    name = qcd.columns[i]
    X1 = new_qcd[f'{name}']
    X2 = new_higgs[f'{name}']
    X3 = new_lowLumi[f'{name}']
    
    w1 = np.ones(X1.size)*new_w_QCD2
    w2 = np.ones(X2.size)*new_w_Higgs2
    w3 = np.ones(X3.size)
    
    bins = 50
    
    row = math.floor(i/2)
    col = i%2
    
    ax[row, col].tick_params(labelsize = 15)
    ax[row, col].tick_params(labelsize = 15)
    temp = ax[row, col].hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], alpha=0.7, weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
    ax[row, col].hist(X3, bins=temp[1], color='thistle', weights=w3, linewidth = 3, label = 'low_Lumi', alpha=0.5)
    ax[row, col].set_title(f'{name}', fontsize = 15, fontweight='bold')
    ax[row, col].grid(linestyle='--', alpha=0.2)
ax[0, 1].legend();

# %%
plt.rcParams["figure.figsize"] = (20,15)

fig, ax = plt.subplots(1, 1)
fig.tight_layout(pad=3.0)

name = 'mass'
X1 = new_qcd[f'{name}']
X2 = new_higgs[f'{name}']
X3 = new_lowLumi[f'{name}']

w1 = np.ones(X1.size)*new_w_QCD2
w2 = np.ones(X2.size)*new_w_Higgs2
w3 = np.ones(X3.size)

bins = 20

ax.tick_params(labelsize = 15)
ax.tick_params(labelsize = 15)
temp = ax.hist([X1, X2], bins, stacked=True, color=['deepskyblue', 'crimson'], alpha=0.7, weights=[w1, w2], linewidth = 3, label = ['qcd', 'stacked qcd+higgs'])
ax.hist(X3, bins=temp[1], color='thistle', weights=w3, linewidth = 3, label = 'low_Lumi', alpha=0.5)
ax.set_title(f'{name}', fontsize = 15, fontweight='bold')
ax.grid(linestyle='--', alpha=0.2)
ax.legend();

# %% [markdown]
# As we can see, the low luminosity data has much fewer events and this is prevalent from the $p_T$ frame axes. Also, since the low luminosity data has fewer events, its data is more "spotty" in all parameters especially after the data cut.

# %% [markdown]
# We repeat the process of finding the significance.

# %%
background = stats.poisson(mu = 3) #Background seems to be at about 3 events
prob = background.sf(8)# Our excess is about 8 events
significance2 = abs(stats.norm.ppf(prob))
significance2
# Out:
# 2.6690777502496226

# %% [markdown]
# The significance is only 2.7 now that our low luminosity has much fewer events which is an observed significance lower than the expected from the simulated data.

# %% [markdown]
# ## Problem 3
